# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s="Shambavi"
s[:3]
# Out:
# 'Sha'

# %%
# no of letters in S
def fun(S):
    count=0
    for i in range(len(s)):
        count+=1
    return count

def fun1(S):
    return len(S)

# option b
def fun2(S):
    return len(set(S))

fun2("Gookool")
# Out:
# 4

# %%
def fun(S):
    p=0
    S.lower()
    for i in range(len(S)):
        print(i,S[i],S[:i])
        if S[i] in S[:i]:
            p+=1
        
    return p
# total number of letters that are repeated in string S more than one time
fun("Gookool") # 2 -o
# Out:
# 0 G
# 1 o G
# 2 o Go
# 3 k Goo
# 4 o Gook
# 5 o Gooko
# 6 l Gookoo
# 3

# %%
s="Gokul"
s.lower()
print(s)
# Out:
# gokul

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
abc=123
abcd=12
print(abcd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 abc=123
# ----> 2 print(abcd)
#
# NameError: name 'abcd' is not defined
