# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1

x=sorted([1,5,3,4,6])
x=[1,3,4,5,6]
y=4
print(binary_search(x,5))
# Out:
# 3

# %% [markdown]
# ## Note : binary search input should always be a `sorted list`
#
# - steps:
#     - assign low=0 and high=len(arr)-1
#     - while low <= high:
#         - assign mid=(low+high)//2  # mid=2
#         - if arr[mid]==target return mid # 4==5?
#         - elif arr[mid]<target:
#             low=mid+1 # 3
#         - else:
#             high=mid-1
#     - return -1

# %%
def binary_search(arr,target):
    low=0
    high=len(arr)-1
    while low <=high:
        mid=(low+high)//2
        if arr[mid]==target:
            return mid
        elif arr[mid]<target:
            low=mid+1
        else:
            high=mid-1
    return -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# fun(0) -> 1 - 2**n - n=0
# fun(1)-> 2 - 2**1
# fun(2)-> fun(1)+fun(1) -> fun(0)+fun(0)+fun(0)+fun(0) - 4  # 2**2
# fun(3)-> 8 # 2**3
# 4 -> 16 # 2**4
# 5 -> 32 # 2**5

# n -> 2**n

# %% [markdown]
# # time complexites
# - `time complexity  means how the time taken by an algorithm grows with the input size`,
# - fun(n)-> 2**n
# - binary_search -> log2(n)
# - sort -> major sort algo -> O(n**2)
# - quick sort, merge sort -> O(n*log2n)

# %% [markdown]
# <!-- binary search -->
#
# - 1024 -> 512 -> 256 -> 128 -> 64 -> 32 -> 16 -> 8 -> 4-> 2->1
#
# - log2(1024) -> O(n) - log n
#
#
# 512 -> 9 => log2(512)
# n ->  log2(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def fun(n):
    k=0
    for i in range(n//2,n): # 5,6,7,8,9
        j=2
        while j<=n:
            k+=n//2 # 15+15+15+15+15 => 75
            j*=2
    return k

fun(10)
# Out:
# 75

# %%
n=10
#- `time complexity  means how the time taken by an algorithm grows with the input size`, 

for i in range(n+10):
    print(i)

for i in range(n):
    print(i)

for i in range(2*n):
    print(i)

for i in range(n*n): # O(n**2)
    print(i)

# O(n) -> even if you add, subtract or mulitiply  ( if you are getting any constant please ignore)


# T.C => 
#   n=10 -> 20
#   n=100 -> 110
#   n=1000000000000000 -> 1000000000000010
